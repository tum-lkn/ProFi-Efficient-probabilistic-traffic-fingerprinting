# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import subprocess as subp
import os
import re
from io import StringIO
from typing import List, Dict, Any, Tuple
# import pyshark

# %%
pth_to_trace = '../data/devel-traces/zoom_firefox_gatherer-01-xm2ks_33048516.pcapng'
hostname = 'zoom.us'

pth_to_trace = '../data/devel-traces/cnet_firefox_gatherer-01-gxjxb_304479.pcapng'
hostname = 'www.cnet.com'

pth_to_trace = '../data/devel-traces/ebay_firefox_gatherer-01-dw2vj_11783345.pcapng'
hostname = 'www.ebay.com'

# %%
def get_ips_from_dns(pth_to_trace: str, hostname: str) -> List[str]:
    dns_cmd = f'tshark -r {pth_to_trace} -Y "dns.resp.name == \"{hostname}\"" -T fields ' \
        '-e frame.number ' \
        '-e frame.time_epoch ' \
        '-e dns.a  ' \
        '-e dns.resp.name  ' \
        '-E header=y -E separator=";"'
    out = subp.check_output(dns_cmd, shell=True)
    print(out)
    dns_replies = pd.read_table(StringIO(out.decode('utf8')), sep=';')
    ips = dns_replies.iloc[0].loc['dns.a'].split(',')
    return ips


def get_client_hello(pth_to_trace: str, ip: str) -> pd.DataFrame:
    client_hello_cmd = f'tshark -r {pth_to_trace} ' \
        f'-Y "tls.handshake.type == 1 && ip.dst=={ip}" ' \
        '-T fields ' \
        '-e frame.number ' \
        '-e frame.time_epoch ' \
        '-e ip.src ' \
        '-e tcp.srcport ' \
        '-e ip.dst ' \
        '-e tcp.dstport ' \
        '-E header=y -E separator=";"'
    out = subp.check_output(client_hello_cmd, shell=True)
    client_hello = pd.read_table(StringIO(out.decode('utf8')), sep=';')
    return client_hello


def four_tuple_from_client_hello(client_hello: pd.DataFrame) -> Tuple[str, int, str, int]:
    src_ip = client_hello.loc[0, 'ip.src']
    src_port = int(client_hello.loc[0, 'tcp.srcport'])
    dst_ip = client_hello.loc[0, 'ip.dst']
    dst_port = int(client_hello.loc[0, 'tcp.dstport'])
    return src_ip, src_port, dst_ip, dst_port


def get_main_flow(pth_to_trace: str, client_hello: pd.DataFrame) -> pd.DataFrame:
    src_ip, src_port, _, _ = four_tuple_from_client_hello(client_hello)
    main_flow_cmd = f'tshark -r {pth_to_trace} ' \
        f'-Y "((ip.src == {src_ip}   && '\
        f'tcp.srcport == {src_port}) || ' \
        f'(ip.dst == {src_ip}        && ' \
        f'tcp.dstport == {src_port})) &&' \
        f'tcp.len > 0" -o tcp.desegment_tcp_streams:false -T fields ' \
        '-e frame.number ' \
        '-e frame.time_epoch ' \
        '-e ip.src ' \
        '-e tcp.srcport ' \
        '-e ip.dst ' \
        '-e tcp.dstport ' \
        '-e tcp.len ' \
        '-e tcp.hdr_len ' \
        '-e tls.record.content_type ' \
        '-e tls.record.length ' \
        '-e tls.record.version ' \
        '-e tls.handshake.type ' \
        '-e ip.hdr_len ' \
        '-e ipv6.nxt ' \
        '-e ipv6.dst ' \
        '-e _ws.col.Info ' \
        '-E header=y -E separator=";"'
    out = subp.check_output(main_flow_cmd, shell=True)
    main_flow = pd.read_table(StringIO(out.decode('utf8')), sep=';')
    return main_flow


def find_tls_record_in_payload(pth_to_trace: int, frame_number: int,
                               major: int, minor: int) -> Tuple[int, int, int, int]:
    tls_cmd = f'tshark -r {pth_to_trace} -Y "frame.number == {frame_number}" ' \
        f'-x -w output.bin | grep -o -E "(14|15|16|17) ' \
        f'{major:02d} {minor:02d} [0-9a-f]{{2}} [0-9a-f]{{2}}"'
    out = subp.check_output(tls_cmd, shell=True)
    bytes = out.decode('utf8').split(' ')
    frame_size = int(bytes[-2] + bytes[-1].strip(), 16)
    record_type = int(bytes[0])
    major = int(bytes[1])
    minor = int(bytes[2])
    return record_type, frame_size, major, minor


def extract_record_info(pth_to_trace: str,frame_number: int, major: int, minor: int) -> Tuple[int, int, int, int]:
    tls_cmd = f'tshark -r {pth_to_trace} -Y "frame.number == {frame_number}" ' \
        f'-x -w output.bin | grep -o -E "(14|15|16|17) {major:02d} {minor:02d} [0-9a-f]{{2}} [0-9a-f]{{2}}"'
    out = subp.check_output(tls_cmd, shell=True)
    bytes = out.decode('utf8').split(' ')
    frame_size = int(bytes[-2] + bytes[-1].strip(), 16)
    record_type = int(bytes[0])
    major = int(bytes[1])
    minor = int(bytes[2])
    return frame_size, record_type, major, minor


def extract_main_flow(pth_to_trace: str, hostname: str) -> pd.DataFrame:
    ips = get_ips_from_dns(pth_to_trace, hostname)
    client_hello = get_client_hello(pth_to_trace, ips[0])
    main_flow = get_main_flow(pth_to_trace, client_hello)
    return main_flow

# %%
print(f'tshark -r {pth_to_trace} -Y "frame.number == 395" -x -w output.bin')
# Out:
# tshark -r ../data/devel-traces/cnet_firefox_gatherer-01-gxjxb_304479.pcapng -Y "frame.number == 395" -x -w output.bin

# %%
out = subp.check_output(f'tshark -r {pth_to_trace} -Y "frame.number == 395" -o tcp.desegment_tcp_streams:FALSE -x -w output.bin', shell=True).decode('utf8')

# %%
len('Frame (1514 bytes):'), len("0000  02 42 ac 11 00 07 02 42 8c 27 ba 23 08 00 45 00   .B.....B.'.#..E.")
# Out:
# (19, 72)

# %%
skip_to = 0

# %%
print(out)
# Out:
# 0000  02 42 ac 11 00 07 02 42 8c 27 ba 23 08 00 45 00   .B.....B.'.#..E.
# 0010  05 dc a5 75 00 00 35 06 24 8f 97 65 72 9a ac 11   ...u..5.$..er...
# 0020  00 07 01 bb e3 8e 0b 1d 9d c0 88 b8 2c 4f 80 10   ............,O..
# 0030  00 8d 2e 79 00 00 01 01 08 0a 09 00 6d 11 9d 3b   ...y........m..;
# 0040  3f 9e bd 08 2b a9 2c 42 89 3c f8 be d5 67 67 92   ?...+.,B.<...gg.
# 0050  ae 49 d9 e8 3a 12 db 9f 33 40 ba b5 ba cc b5 ae   .I..:...3@......
# 0060  43 58 44 80 53 c8 c7 0f af e0 82 d7 67 43 17 03   CXD.S.......gC..
# 0070  03 05 73 66 a6 78 ea ef 6e 0c f2 cd a6 d2 07 a1   ..sf.x..n.......
# 0080  8d 94 9c 9b a0 81 49 c7 f1 89 fc f8 f8 a7 63 f5   ......I.......c.
# 0090  1c 51 ab d5 35 16 7d 7d 23 71 82 9c 39 eb 87 04   .Q..5.}}#q..9...
# 05b0  31 c1 55 c7 86 14 59 5d 6f 9e c9 02 91 d4 98 55   1.U...Y]o......U
# 05c0  2e 16 0a c3 b6 fc bb 81 55 5c fb 95 f8 68 78 ac   ........U\...hx.
# 05d0  aa e9 21 98 23 0a 05 70 2b 52 be 57 18 46 86 b4   ..!.#..p+R.W.F..
# 05e0  23 cc 5f 9b 58 ec 17 03 03 05                     #._.X.....

# %%
len('0010  05 dc a5 75 00 00 35 06 24 8f 97 65 72 9a ac 11')
# Out:
# 53

# %%
[s[6:53].strip() for s in out[skip_to:].split(os.linesep)]
# Out:
# ['02 42 ac 11 00 07 02 42 8c 27 ba 23 08 00 45 00',
#  '05 dc a5 75 00 00 35 06 24 8f 97 65 72 9a ac 11',
#  '00 07 01 bb e3 8e 0b 1d 9d c0 88 b8 2c 4f 80 10',
#  '00 8d 2e 79 00 00 01 01 08 0a 09 00 6d 11 9d 3b',
#  '3f 9e bd 08 2b a9 2c 42 89 3c f8 be d5 67 67 92',
#  'ae 49 d9 e8 3a 12 db 9f 33 40 ba b5 ba cc b5 ae',
#  '43 58 44 80 53 c8 c7 0f af e0 82 d7 67 43 17 03',
#  '03 05 73 66 a6 78 ea ef 6e 0c f2 cd a6 d2 07 a1',
#  '8d 94 9c 9b a0 81 49 c7 f1 89 fc f8 f8 a7 63 f5',
#  '1c 51 ab d5 35 16 7d 7d 23 71 82 9c 39 eb 87 04',
#  '96 e5 26 6d 79 fc ea 43 d3 09 58 a7 1c 6f cc 14',
#  'bb 6d b8 14 00 4e 1d 38 2b 9f 0c a3 71 48 04 cf',
#  '76 72 05 31 de 98 42 a3 3b a8 8f 26 1b a9 1f ea',
#  '6f 2a bb cc 0b de 36 ba 51 ed c5 94 61 fc 9f 30',
#  'c4 1a 89 89 01 13 25 bf 90 e8 9c b5 89 6d b8 69',
#  '5a 1f c7 4e dd 36 4c f5 0e 91 b3 80 cc ec 38 0d',
#  '73 46 85 f7 bb 99 c7 16 0a 73 0b db de 96 be 06',
#  '92 cc 34 7c 8b 30 e7 63 d9 fc 53 42 2a 18 20 99',
#  '06 80 ed 60 ba ad ef ad a9 64 40 16 1c e9 0d e3',
#  '67 7c ee 12 66 32 24 bc b2 03 b4 20 b3 1a eb f4',
#  '85 35 8b 28 12 19 3b 83 64 1c 88 6d 36 ae 01 dd',
#  '1e 5b 38 7a 0b ee fb 30 7d ad 33 33 71 b3 8f 35',
#  '36 9b af 84 e4 12 af f3 c5 ac 72 d1 c7 a3 eb 2f',
#  'f9 5a 5b 99 cf 6f bb 0f eb de b5 b0 b4 5e 44 15',
#  'f4 75 94 65 59 cc dc 0b 83 2d 22 1c 01 1c bc cd',
#  '13 eb bb 82 ff fa 85 a5 12 d2 42 e2 7f 79 fb bd',
#  '3a 30 88 59 98 e8 6f 70 2b 3a c5 f0 b5 22 68 37',
#  '1e c7 10 72 35 14 72 43 1b 85 28 e2 9a 44 f2 d2',
#  'ba df 82 62 1e 1d b3 a4 2a 58 34 9a d1 05 58 58',
#  '2c 96 fd 26 f5 40 7a d8 a8 20 7b 25 6f f8 3a 3b',
#  '2c d4 d2 3a 4c e8 50 54 55 07 db 6f 57 03 5e d1',
#  '69 99 87 d1 0c cc ad 39 1a b2 a0 b9 31 97 7d 76',
#  '59 59 ca b0 a3 8f 52 5e ec 15 30 c3 aa 32 ac ff',
#  'ea 3f e3 86 82 39 8c af 44 db 62 d4 74 74 27 22',
#  'c4 4f 14 6d c8 dd 2c e2 cc f8 b9 0c f5 14 72 b6',
#  'f4 c6 9f d2 c0 e9 ee 44 c9 92 78 eb a2 25 88 f3',
#  '6a 89 6a 90 f1 5a 92 e2 1a 93 24 2c d3 73 fc 2c',
#  '97 e3 6e 1d fc 93 a6 d8 50 bd 61 22 7b 8a 95 ba',
#  '4d 89 c2 04 b7 f9 0d 7c 4d cd 5d 4c 2f 44 9e 26',
#  'ae 7a b1 a6 f1 af 7e 54 68 d6 27 cf 40 a1 75 47',
#  'f7 61 a0 b7 14 8e 5a 23 a1 1f 8b 01 18 e0 84 7f',
#  'ab ea 33 c8 e5 b0 4a 43 fe 93 7b 47 b9 93 ef 15',
#  '41 dc c1 57 9e 0b ca 31 a7 00 78 45 82 c5 e7 04',
#  '45 fb 37 6f b5 21 f9 3c 4c f6 66 d2 cb c5 18 13',
#  '2c 1c 1b 06 67 a4 30 e6 32 fa 6b f1 fd 81 4a 34',
#  '00 5e c4 ad 4b b1 14 dc 95 55 2a e9 78 4d a6 ac',
#  'cd ea 59 b1 6c 10 52 36 9c 86 16 b8 12 f3 f9 3a',
#  '62 01 b8 cd a9 a4 64 8d b4 ee 7a a0 ba 9b d2 3d',
#  '45 71 b1 7e 7b 5e f4 de a6 c1 ec c4 d1 66 72 37',
#  '24 4a 23 40 43 30 aa c2 23 59 51 73 f6 a1 25 4b',
#  '82 f7 48 ed 57 4b 9a cb 14 72 1f 6d a2 a6 a1 cb',
#  'cf 8f 0c d4 40 6a 5e 4a 8e db e9 9f 38 40 c8 d4',
#  '0a ba ca f5 a9 38 a6 30 1c d4 da eb cb 76 f9 50',
#  '48 80 4e 06 f3 2d 80 cb 36 36 74 3f 89 6d 1d 5a',
#  '89 01 7f 38 00 35 b8 ae 47 1d 07 71 16 1f cb 43',
#  '31 c1 55 c7 86 14 59 5d 6f 9e c9 02 91 d4 98 55',
#  '2e 16 0a c3 b6 fc bb 81 55 5c fb 95 f8 68 78 ac',
#  'aa e9 21 98 23 0a 05 70 2b 52 be 57 18 46 86 b4',
#  '23 cc 5f 9b 58 ec 17 03 03 05',
#  '',
#  '']

# %%
pattern = re.compile(
        "(?P<numBytes0>[0-9a-f]{4})?"              
        "(?P<anyBytes0>  ([0-9a-f]{2} )*)?"        
        "(?P<recType>14|15|16|17)"               
        "((?P<ascii1>   .{16}\n)(?P<numBytes2>[0-9a-f]{4} ))?"   
        " (?P<major>0[123])"
        "((?P<ascii2>   .{16}\n)(?P<numBytes3>[0-9a-f]{4} ))?"   
        " (?P<minor>0[123])"
        "((?P<ascii3>   .{16}\n)(?P<numBytes4>[0-9a-f]{4} ))?"   
        " (?P<length0>[0-9a-f]{2})"              
        "((?P<ascii4>   .{16}\n)(?P<numBytes5>[0-9a-f]{4} ))?"   
        " (?P<length1>[0-9a-f]{2})"
        "((?P<ascii5>   .{16}\n)(?P<numBytes6>[0-9a-f]{4} ))?"
        " (?P<handshakeType>[0-9a-f]{2})"
    )

# %%
s = """0090  00 00 00 00 4e 12 ea 29 41 9f 08 a7 ce 89 b3 00   ....N..)A.......
0080  d7 14 03 03 00 01 01 16 03 03 00 28 00 00 00 00   ...........(....
0090  00 00 00 00 4e 12 ea 29 41 9f 08 a7 ce 89 b3 00   ....N..)A.......
00a0  19 20 40 04 ad 65 5a 4d fa a4 72 90 69 dd a1 29   . @..eZM..r.i..)
00b0  57 8a 63 16                                       W.c."""
m = pattern.search(s)

# %%
m.span()
# Out:
# (73, 117)

# %%
def extract_record_info_re(pth_to_trace: str, frame_number: int, byte_offset=0) -> Dict[str, str]:
    
    # Match byte numbers.
    # Match any sequence of bytes.
    # Match TLS record type.
    # End of row. Match ASCII output, new line and byte numbers.
    # Match TLS major version.
    # End of row. Match ASCII output, new line and byte numbers.
    # Match TLS minor version.
    # End of row. Match ASCII output, new line and byte numbers.
    # Match first byte of TLS record length.
    # End of row. Match ASCII output, new line and byte numbers.
    # Match second byte of TLS record length.
    # End of row. Match ASCII output, new line and byte numbers.
    # Match handshake type. Only valid if record type is 22, i.e., 0x16
    pattern = re.compile(
        "(?P<numBytes0>[0-9a-f]{4})?"              
        "(?P<anyBytes0>  ([0-9a-f]{2} )*)?"        
        "(?P<recType>14|15|16|17)"               
        "((?P<ascii1>   .{16}\n)(?P<numBytes2>[0-9a-f]{4} ))?"   
        " (?P<major>0[123])"
        "((?P<ascii2>   .{16}\n)(?P<numBytes3>[0-9a-f]{4} ))?"   
        " (?P<minor>0[123])"
        "((?P<ascii3>   .{16}\n)(?P<numBytes4>[0-9a-f]{4} ))?"   
        " (?P<length0>[0-9a-f]{2})"              
        "((?P<ascii4>   .{16}\n)(?P<numBytes5>[0-9a-f]{4} ))?"   
        " (?P<length1>[0-9a-f]{2})"
        "((?P<ascii5>   .{16}\n)(?P<numBytes6>[0-9a-f]{4} ))?"
        " (?P<handshakeType>[0-9a-f]{2})"
    )
    num_rows = int(byte_offset / 16)
    remove_rows = num_rows * 73
    tls_cmd = f'tshark -r {pth_to_trace} -Y "frame.number == {frame_number}" -x -w output.bin'
    out = subp.check_output(tls_cmd, shell=True).decode('utf8')
    match = pattern.search(out[remove_rows:])
    
    if match is not None:
        groupdict = match.groupdict()
        num_bytes = len(groupdict['anyBytes0'].strip().split(' '))
        if num_rows * 16 + num_bytes > byte_offset + 2:
            start, stop = match.span()
            match2 = pattern.search(out[remove_rows + start:remove_rows + stop - 17])
            if match2 is not None:
                 match = match2
    else:
        print("Match is None for ", out[remove_rows:])
    #if match is not None:
    #    start, stop = match.span()
    #    print("BEFORE MATCH", out[remove_rows + start:remove_rows + stop - 17])
    #    match2 = pattern.search(out[remove_rows + start:remove_rows + stop - 17])
    #    if match2 is not None:
    #        match = match2
    return None if match is None else match.groupdict()


def frame_size_from_group_dict(groupdict: Dict[str, str]) -> int:
    return int(groupdict['length0'].strip() + groupdict['length1'].strip(), 16)


def get_frame_size(groupdict: Dict[str, str]) -> int:
    return int(groupdict['length0'].strip() + groupdict['length1'].strip(), 16)


def get_record_type(groupdict: Dict[str, str]) -> int:
    return int(groupdict['recType'], 16)


def get_handshake_type(groupdict: Dict[str, str]) -> int:
    return int(groupdict['handshakeType'], 16)


def get_major_version(groupdict: Dict[str, str]) -> int:
    return int(groupdict['major'], 16)


def get_minor_version(groupdict: Dict[str, str]) -> int:
    return int(groupdict['minor'], 16)


def get_header_start_byte_from_group_dict(groupdict: Dict[str, str], tcp_header_offset: int) -> int:
    tmp = groupdict['numBytes0'].lstrip('0')
    row_offset = 0 if len(tmp) == 0 else int(tmp, 16)
    tmp = groupdict['anyBytes0'].strip()
    col_offset = 0 if len(tmp) == 0 else len(tmp.split(' '))
    return row_offset + col_offset - tcp_header_offset

# %%
def add_labels(pth_to_trace: str, main_flow: pd.DataFrame) -> pd.DataFrame:
    frame_size, record, major, minor = find_tls_record_in_payload(pth_to_trace, frame_number, major, minor)
    
    
def packet_starts_with_tls_header(pth_to_trace: str, frame_number: int,
                                  major: int, minor: int) -> bool:
    first = 54
    second = 55
    third = 56
    cmd = f'tshark -r {pth_to_trace} -Y "frame.number == {frame_number} && (frame[{first}] == 14 || '\
          f'frame[{first}] == 15 || '\
          f'frame[{first}] == 16 || '\
          f'frame[{first}] == 17) && '\
          f'frame[{second}] == {major:02d} && frame[{third}] == {minor:02d}"'
    out = subp.check_output(cmd, shell=True)
    if len(out.decode('utf8')) > 0:
        return True
    else:
        return False

# %%
groupdict = extract_record_info_re(pth_to_trace, 158, 3, 3)
print(groupdict)
print(frame_size_from_group_dict(groupdict))
print(get_header_start_byte_from_group_dict(groupdict))
# Out:
# {'numBytes0': '04e0', 'anyBytes0': '  d0 3f 1f 65 2a 2e b7 1f b0 c4 4b ', 'recType': '17', 'ascii1': None, 'numBytes2': None, 'major': '03', 'ascii2': None, 'numBytes3': None, 'minor': '03', 'ascii3': None, 'numBytes4': None, 'length0': '10', 'ascii4': None, 'numBytes5': None, 'length1': '18', 'ascii5': '   .?.e*.....K.....\n', 'numBytes6': '04f0 ', 'handshakeType': 'e8'}
# 4120
# 1205

# %%
packet_starts_with_tls_header(pth_to_trace, 74, 3, 3)
# Out:
# True

# %%
groupdict['anyBytes0']
# Out:
# '  d0 3f 1f 65 2a 2e b7 1f b0 c4 4b '

# %%
ips = get_ips_from_dns(pth_to_trace, hostname)
ips
# Out:
# b'frame.number;frame.time_epoch;dns.a;dns.resp.name\n'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-9218e24f947f> in <module>
# ----> 1 ips = get_ips_from_dns(pth_to_trace, hostname)
#       2 ips
#
# <ipython-input-55-0f004a18e9c5> in get_ips_from_dns(pth_to_trace, hostname)
#       9     print(out)
#      10     dns_replies = pd.read_table(StringIO(out.decode('utf8')), sep=';')
# ---> 11     ips = dns_replies.iloc[0].loc['dns.a'].split(',')
#      12     return ips
#      13
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1499
#    1500             # validate the location
# -> 1501             self._validate_integer(key, axis)
#    1502
#    1503             return self.obj._ixs(key, axis=axis)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1442         len_axis = len(self.obj._get_axis(axis))
#    1443         if key >= len_axis or key < -len_axis:
# -> 1444             raise IndexError("single positional indexer is out-of-bounds")
#    1445
#    1446     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
client_hello = get_client_hello(pth_to_trace, ip)
client_hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6dd01b21c333> in <module>
# ----> 1 client_hello = get_client_hello(pth_to_trace, ip)
#       2 client_hello
#
# NameError: name 'ip' is not defined

# %%
main_flow = get_main_flow(pth_to_trace, client_hello)
main_flow
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f354fadb2dae> in <module>
# ----> 1 main_flow = get_main_flow(pth_to_trace, client_hello)
#       2 main_flow
#
# NameError: name 'client_hello' is not defined

# %%
frame_number = 154
major = 3
minor = 3

# %%
main_flow = extract_main_flow(pth_to_trace, hostname)
main_flow
# Out:
#      frame.number  frame.time_epoch      ip.src  tcp.srcport      ip.dst  \
# 0              14      1.618085e+09  172.17.0.2        40704  65.9.28.69
# 1              17      1.618085e+09  65.9.28.69          443  172.17.0.2
# 2              19      1.618085e+09  65.9.28.69          443  172.17.0.2
# 3              21      1.618085e+09  65.9.28.69          443  172.17.0.2
# 4              23      1.618085e+09  65.9.28.69          443  172.17.0.2
# ..            ...               ...         ...          ...         ...
# 304           662      1.618085e+09  65.9.28.69          443  172.17.0.2
# 305           663      1.618085e+09  65.9.28.69          443  172.17.0.2
# 306           665      1.618085e+09  65.9.28.69          443  172.17.0.2
# 307           666      1.618085e+09  65.9.28.69          443  172.17.0.2
# 308           668      1.618085e+09  65.9.28.69          443  172.17.0.2
#
#      tcp.dstport  tcp.len  tcp.hdr_len tls.record.content_type  \
# 0            443      517           32                      22
# 1          40704     1428           32                   22,20
# 2          40704     1428           32                     NaN
# 3          40704     1428           32                     NaN
# 4          40704     1428           32                     NaN
# ..           ...      ...          ...                     ...
# 304        40704     1428           32                     NaN
# 305        40704     1428           32                     NaN
# 306        40704     1428           32                     NaN
# 307        40704     1428           32                     NaN
# 308        40704      390           32                     NaN
#
#     tls.record.length                tls.record.version  tls.handshake.type  \
# 0                 512                        0x00000301                 1.0
# 1            122,1,36  0x00000303,0x00000303,0x00000303                 2.0
# 2                 NaN                               NaN                 NaN
# 3                 NaN                               NaN                 NaN
# 4                 NaN                               NaN                 NaN
# ..                ...                               ...                 ...
# 304               NaN                               NaN                 NaN
# 305               NaN                               NaN                 NaN
# 306               NaN                               NaN                 NaN
# 307               NaN                               NaN                 NaN
# 308               NaN                               NaN                 NaN
#
#      ip.hdr_len  ipv6.nxt  ipv6.dst  \
# 0            20       NaN       NaN
# 1            20       NaN       NaN
# 2            20       NaN       NaN
# 3            20       NaN       NaN
# 4            20       NaN       NaN
# ..          ...       ...       ...
# 304          20       NaN       NaN
# 305          20       NaN       NaN
# 306          20       NaN       NaN
# 307          20       NaN       NaN
# 308          20       NaN       NaN
#
# 38                        0x00000303
# 39                        0x00000303
# 40                        0x00000303
# 41                        0x00000303
# 42                        0x00000303
# 43                        0x00000303
#
#                                          _ws.col.Info
# 0                                        Client Hello
# 1   Server Hello, Change Cipher Spec, Application ...
# 2                                    Application Data
# 3                Change Cipher Spec, Application Data
# 4                                    Application Data
# 5                                    Application Data
# 6                                    Application Data
# 7                                    Application Data
# 8                                    Application Data
# 9                                    Application Data
# 10                                   Application Data
# 11                                   Application Data
# 12                 [TCP segment of a reassembled PDU]
# 13  Application Data [TCP segment of a reassembled...
# 14  Application Data [TCP segment of a reassembled...
# 15  Application Data [TCP segment of a reassembled...
# 16  Application Data [TCP segment of a reassembled...
# 17  Application Data [TCP segment of a reassembled...
# 18  Application Data [TCP segment of a reassembled...
# 19  Application Data [TCP segment of a reassembled...
# 20  Application Data [TCP segment of a reassembled...
# 21  Application Data [TCP segment of a reassembled...
# 22  443 → 51102 [ACK] Seq=17489 Ack=1132 Win=67840...
# 23  Application Data [TCP segment of a reassembled...
# 24  Application Data [TCP segment of a reassembled...
# 25  Application Data [TCP segment of a reassembled...
# 26  Application Data [TCP segment of a reassembled...
# 27                 Application Data, Application Data
# 28                 [TCP segment of a reassembled PDU]
# 29  Application Data [TCP segment of a reassembled...
# 30  Application Data [TCP segment of a reassembled...
# 31  Application Data [TCP segment of a reassembled...
# 32  Application Data [TCP segment of a reassembled...
# 33  Application Data [TCP segment of a reassembled...
# 34  Application Data [TCP segment of a reassembled...
# 35                                   Application Data
# 36                                   Application Data
# 37                 [TCP segment of a reassembled PDU]
# 38                                   Application Data
# 39                                   Application Data
# 40                                   Application Data
# 41                                   Application Data
# 42                                   Application Data
# 43                                   Application Data

# %%
TLS_MAP = {
    20: 'CHANGE_CIPHER_SPEC',
    21: 'ALERT',
    22: {
        1: 'CLIENT_HELLO',
        2: 'SERVER_HELLO',
        11: 'CERTIFICATE',
        12: 'SERVER_KEY_EXCHANGE',
        13: 'CERTIFICATE_REQUEST',
        14: 'SERVER_DONE',
        15: 'CERTIFICATE_VERIFY',
        16: 'CLIENT_KEY_EXCHANGE',
        20: 'FINISHED'
    },
    23: 'APPLICATION_DATA'
}


class MainFlow(object):
    """
    Represents a main flow of a trace.
    """
    def __init__(self, src_ip: str, src_port: int, dst_ip: str, dst_port: int,
                 tcp_header_length: int, ip_header_length: int):
        self.src_ip = src_ip
        self.src_port = src_port
        self.dst_ip = dst_ip
        self.dst_port = dst_port
        self.tls_records = []
        self.frames = []
        self.tcp_header_length = tcp_header_length
        self.ip_header_length = ip_header_length

    def __str__(self) -> str:
        s = f'Flow: {self.src_ip}\t{self.src_port}\t{self.dst_ip}\t{self.dst_port}'
        s += '\n\t' + '\n\t'.join([str(f) for f in self.frames]) if len(self.frames) > 0 else ''
        return s


class TlsRecord(object):
    """
    Represents a TLS record.
    """
    header_size = 5

    @classmethod
    def from_record(cls, record: 'TlsRecord') -> 'TlsRecord':
        return cls(
            length=record.length,
            content_type=record.content_type,
            minor_version=record.minor_version,
            major_version=record.major_version,
            record_number=record.record_number,
            header_start_byte=record.header_start_byte,
            handshake_type=record.handshake_type,
            direction=record.direction
        )

    def __init__(self, length: int, content_type: int, minor_version: int,
                 major_version: int, record_number: int, direction: int,
                 header_start_byte: int, handshake_type: int=None):
        self.length = length
        self.content_type = content_type
        self.minor_version = minor_version
        self.major_version = major_version
        self.record_number = record_number
        self.handshake_type = handshake_type
        self.header_start_byte = header_start_byte
        self.direction = direction

    def __str__(self) -> str:
        d = 'outbound' if self.direction < 0 else 'inbound'
        msg_type = TLS_MAP[self.content_type]
        if self.content_type == 22:
            try:
                msg_type = TLS_MAP[self.content_type][self.handshake_type]
            except Exception as e:
                msg_type = f"ENCRYPTED_HANDSHAKE_MESSAGE {self.handshake_type}"
        s = f'Record: {self.record_number}\t{msg_type:30s}\t' + \
            f'{self.major_version}\t{self.minor_version}\t{d:8s}\t{self.header_start_byte}->{self.length}'
        return s


class Frame(object):
    """
    Represents a normal L2 frame.
    """
    def __init__(self, tcp_length: int, frame_number: int, time_epoch: float, direction: int,
                 tcp_header_offset: int):
        self.tcp_length = tcp_length
        self.frame_number = frame_number
        self.time_epoch = time_epoch
        self.tls_records = []
        self.direction = direction
        self.tcp_header_offset = tcp_header_offset

    def __str__(self) -> str:
        d = 'outbound' if self.direction < 0 else 'inbound'
        s = f"Frame: {self.frame_number}\t{self.time_epoch}\t{d:8s}\t{self.tcp_length}"
        s += '\n\t\t' + '\n\t\t'.join([str(r) for r in self.tls_records]) if len(self.tls_records) > 0 else ''
        return s


def find_records(pth_to_trace: str, frame: Frame, record_number: int,
                   offset: int, records: List[TlsRecord]) -> int:
    groupdict = extract_record_info_re(pth_to_trace, frame.frame_number, byte_offset=offset)
    # print("\t\t", str(groupdict))
    if groupdict is None:
        raise ValueError(f"GroupDict is none for frame {str(frame)}")
    else:
        record = TlsRecord(
            length=frame_size_from_group_dict(groupdict),
            content_type=get_record_type(groupdict),
            major_version=get_major_version(groupdict),
            minor_version=get_minor_version(groupdict),
            direction=frame.direction,
            record_number=record_number,
            header_start_byte=get_header_start_byte_from_group_dict(groupdict, frame.tcp_header_offset),
        )
        if record.content_type == 22:
            record.handshake_type = get_handshake_type(groupdict)
        records.append(record)

        remaining_payload = frame.tcp_length - record.header_start_byte - record.header_size
        if remaining_payload <= record.length:
            return record.length - remaining_payload
        else:
            return find_records(
                pth_to_trace=pth_to_trace,
                frame=frame,
                record_number=record_number + 1,
                offset = record.header_start_byte + record.header_size + record.length + frame.tcp_header_offset,
                records=records
            )


def new_row(main_flow: pd.DataFrame, i: int) -> Dict[str, Any]:
    frame_number = int(main_flow.loc[i, 'frame.number'])
    row = {}
    row['frame_number'] = frame_number
    row['frame.time_epoch'] = main_flow.at[i, 'frame.time_epoch']
    row['ip.src'] = main_flow.at[i, 'ip.src']
    row['tcp.srcport'] = main_flow.at[i, 'tcp.srcport']
    row['ip.dst'] = main_flow.at[i, 'ip.dst']
    row['tcp.dstport'] = main_flow.at[i, 'tcp.dstport']
    row['tcp.len'] = main_flow.at[i, 'tcp.len']
    row['tls.frame_number'] = 0 if len(rows) == 0 else rows[-1]['tls.frame_number'] + 1
    row['tls.handshake.type'] = None
    row['tls.record.version.major'] = None
    row['tls.record.version.minor'] = None
    return row


def packet_part_of_previous_frame(row: Dict[str, any]) -> Dict[str, Any]:
    print("\tPacket belongs to previous TLS frame.")
    row['tls.record.version.major'] = rows[-1]['tls.record.version.major']
    row['tls.record.version.minor'] = rows[-1]['tls.record.version.minor']
    row['tls.frame_number'] = rows[-1]['tls.frame_number']
    row['tls.record.content_type'] = rows[-1]['tls.record.content_type']
    row['tls.record.length'] = None
    return row


def packet_contains_new_frame(row: Dict[str, any], frame_number: int, offset: int):
    groupdict = extract_record_info_re(
        pth_to_trace,
        frame_number,
        major,
        minor,
        offset
    )
    row['tls.frame_number'] = row['tls.frame_number'] + 1
    row['tls.record.content_type'] = int(groupdict['recType'])
    row['tls.record.length'] = frame_size_from_group_dict(groupdict)
    row['tls.handshake.typ'] = None
    frame_starts_at = get_header_start_byte_from_group_dict(groupdict)
    return row, frame_starts_at

# %%
# 72: 16 03 01 01 fc 01 --> Client Hello, 508
# 74: 16 03 03 00 6a 02 --> Server Hello, 106
#     16 03 03 0f 03 0b --> Certificate, 3843
# 75: Copy
# 76: Copy
#     16 03 03 01 df 16 --> Unknown Handshake, 479
# 80: Copy
#     16 03 03 01 4d 0c --> Server Key Exchange, 333
#     16 03 03 00 04 0e --> Server Done
def label_main_flow(pth_to_trace: str, main_flow: pd.DataFrame) -> MainFlow:
    flow = MainFlow(
        src_ip=main_flow.at[0, 'ip.src'],
        src_port=int(main_flow.at[0, 'tcp.srcport']),
        dst_ip=main_flow.at[0, 'ip.dst'],
        dst_port=int(main_flow.at[0, 'tcp.dstport']),
        tcp_header_length=int(main_flow.at[0, 'tcp.hdr_len']),
        ip_header_length=int(main_flow.at[0, 'ip.hdr_len'])
    )
    remaining_bytes = {flow.src_ip: 0, flow.dst_ip: 0}
    for row_idx in range(main_flow.shape[0]):
        frame_src_ip = main_flow.at[row_idx, 'ip.src']
        records = []
        frame = Frame(
            tcp_length=main_flow.at[row_idx, 'tcp.len'],
            frame_number=main_flow.at[row_idx, 'frame.number'],
            time_epoch=main_flow.at[row_idx, 'frame.time_epoch'],
            direction=-1 if main_flow.at[row_idx, 'ip.src'] == flow.src_ip else 1,
            tcp_header_offset=14 + flow.tcp_header_length + flow.ip_header_length
        )
        # print("New frame: ", str(frame))
        # print("\tremaining_bytes", remaining_bytes)
        if remaining_bytes[frame_src_ip] == 0:
            records = []
            remaining_bytes[frame_src_ip] = find_records(
                pth_to_trace=pth_to_trace,
                frame=frame,
                record_number=len(flow.tls_records),
                offset=remaining_bytes[frame_src_ip] + frame.tcp_header_offset,
                records=records
            )
            frame.tls_records.extend(records)
        else:
            record = TlsRecord.from_record(flow.tls_records[-1])
            record.direction = frame.direction
            # print("\tCopy Record: ", str(record))
            frame.tls_records.append(record)
            if remaining_bytes[frame_src_ip] < frame.tcp_length:
                records = []
                remaining_bytes[frame_src_ip] = find_records(
                    pth_to_trace=pth_to_trace,
                    frame=frame,
                    record_number=len(flow.tls_records),
                    offset=remaining_bytes[frame_src_ip] + frame.tcp_header_offset,
                    records=records
                )
                frame.tls_records.extend(records)
            else:
                remaining_bytes[frame_src_ip] -= frame.tcp_length
        print(frame.frame_number, frame_src_ip, remaining_bytes[frame_src_ip])
        flow.frames.append(frame)
        flow.tls_records.extend(records)
    return flow
    

# pth_to_trace = '../data/devel-traces/zoom_firefox_gatherer-01-xm2ks_33048516.pcapng'
# hostname = 'zoom.us'

pth_to_trace = '../data/devel-traces/ebay-kleinanzeigen_firefox_gatherer-01-2ptv6_63946056.pcapng'
hostname = 'www.ebay-kleinanzeigen.de'

pth_to_trace = '../data/devel-traces/instagram_chromium_gatherer-01-4tss9_38712719.pcapng'
hostname = 'help.instagram.com'

pth_to_trace = '../data/devel-traces/instagram_chromium_gatherer-01-4tss9_91246581.pcapng'
hostname = 'help.instagram.com'

pth_to_trace = '../data/devel-traces/smallpdf_chromium_gatherer-01-kqkdk_46263679.pcapng'
hostname = 'smallpdf.com'

main_flow = extract_main_flow(pth_to_trace, hostname)
flow = label_main_flow(pth_to_trace, main_flow)
print('\n===================================================')
print(flow)
# Out:
# 14 172.17.0.2 0
# 17 65.9.28.69 4091
# 19 65.9.28.69 2663
# 21 65.9.28.69 1235
# 23 65.9.28.69 93
# 25 65.9.28.69 0
# 30 172.17.0.2 0
# 31 172.17.0.2 0
# 32 172.17.0.2 0
# 34 65.9.28.69 0
# 36 172.17.0.2 0
# 38 65.9.28.69 0
# 41 65.9.28.69 14978
# 43 65.9.28.69 13550
# 45 65.9.28.69 12122
# 47 65.9.28.69 10694
# 49 65.9.28.69 9266
# 51 65.9.28.69 7838
# 52 65.9.28.69 6410
# 54 65.9.28.69 4982
# 55 65.9.28.69 3554
# 57 65.9.28.69 2126
# 58 65.9.28.69 698
# 60 65.9.28.69 15676
# 61 65.9.28.69 14248
# 63 65.9.28.69 12820
# 64 65.9.28.69 11392
# 66 65.9.28.69 9964
# 67 65.9.28.69 8536
# 69 65.9.28.69 7108
# 70 65.9.28.69 5680
# 72 65.9.28.69 4252
# 73 65.9.28.69 2824
# 75 65.9.28.69 1396
# 76 65.9.28.69 16374
# 78 65.9.28.69 14946
# 79 65.9.28.69 13518
# 81 65.9.28.69 12090
# 82 65.9.28.69 10662
# 84 65.9.28.69 9234
# 85 172.17.0.2 0
# 86 172.17.0.2 0
# 87 65.9.28.69 7806
# 88 65.9.28.69 6378
# 91 65.9.28.69 4950
# 93 65.9.28.69 3522
# 95 172.17.0.2 0
# 96 172.17.0.2 0
# 97 172.17.0.2 0
# 98 172.17.0.2 0
# 99 172.17.0.2 0
# 100 172.17.0.2 0
# 101 65.9.28.69 2094
# 102 65.9.28.69 666
# 104 65.9.28.69 13060
# 105 65.9.28.69 11632
# 107 65.9.28.69 10204
# 108 65.9.28.69 8776
# 111 65.9.28.69 7348
# 112 65.9.28.69 5920
# 114 65.9.28.69 4492
# 601 65.9.28.69 10767
# 603 65.9.28.69 9339
# 609 65.9.28.69 7911
# 611 65.9.28.69 6483
# 612 65.9.28.69 5055
# 614 65.9.28.69 3627
# 615 65.9.28.69 2199
# 617 65.9.28.69 771
# 618 65.9.28.69 15749
# 620 65.9.28.69 14321
# 621 65.9.28.69 12893
# 623 65.9.28.69 11465
# 624 65.9.28.69 10037
# 626 65.9.28.69 8609
# 627 65.9.28.69 7181
# 629 65.9.28.69 5753
# 630 65.9.28.69 4325
# 632 65.9.28.69 2897
# 633 65.9.28.69 1469
# 635 65.9.28.69 41
# 636 65.9.28.69 15019
# 638 65.9.28.69 13591
# 639 65.9.28.69 12163
# 641 65.9.28.69 10735
# 642 65.9.28.69 9307
# 644 65.9.28.69 7879
# 645 65.9.28.69 6451
# 647 65.9.28.69 5023
# 648 65.9.28.69 3595
# 650 65.9.28.69 2167
# 651 65.9.28.69 739
# 653 65.9.28.69 13242
# 654 65.9.28.69 11814
# 656 65.9.28.69 10386
# 657 65.9.28.69 8958
# 659 65.9.28.69 7530
# 660 65.9.28.69 6102
# 662 65.9.28.69 4674
# 663 65.9.28.69 3246
# 665 65.9.28.69 1818
# 666 65.9.28.69 390
# 668 65.9.28.69 0
#
# ===================================================
# Flow: 172.17.0.2	40704	65.9.28.69	443
# 	Frame: 14	1618084979.695247	outbound	517
# 		Record: 0	CLIENT_HELLO                  	3	1	outbound	0->512
# 	Frame: 17	1618084979.728808	inbound 	1428
# 		Record: 1	SERVER_HELLO                  	3	3	inbound 	0->122
# 		Record: 2	CHANGE_CIPHER_SPEC            	3	3	inbound 	127->1
# 		Record: 3	APPLICATION_DATA              	3	3	inbound 	133->36
# 		Record: 4	APPLICATION_DATA              	3	3	inbound 	174->5340
# 	Frame: 19	1618084979.729067	inbound 	1428
# 		Record: 4	APPLICATION_DATA              	3	3	inbound 	174->5340
# 	Frame: 21	1618084979.729072	inbound 	1428
# 		Record: 4	APPLICATION_DATA              	3	3	inbound 	174->5340
# 	Frame: 23	1618084979.730997	inbound 	1428
# 		Record: 4	APPLICATION_DATA              	3	3	inbound 	174->5340
# 		Record: 5	APPLICATION_DATA              	3	3	inbound 	1235->281
# 	Frame: 25	1618084979.731003	inbound 	151
# 		Record: 5	APPLICATION_DATA              	3	3	inbound 	1235->281
# 		Record: 6	APPLICATION_DATA              	3	3	inbound 	93->53
# 	Frame: 30	1618084979.821943	outbound	64
# 		Record: 7	CHANGE_CIPHER_SPEC            	3	3	outbound	0->1
# 		Record: 8	APPLICATION_DATA              	3	3	outbound	6->53
# 	Frame: 31	1618084979.822222	outbound	92
# 		Record: 9	APPLICATION_DATA              	3	3	outbound	0->87
# 	Frame: 32	1618084979.822567	outbound	363
# 		Record: 10	APPLICATION_DATA              	3	3	outbound	0->358
# 	Frame: 34	1618084979.854656	inbound 	62
# 		Record: 11	APPLICATION_DATA              	3	3	inbound 	0->57
# 	Frame: 36	1618084979.854828	outbound	31
# 		Record: 12	APPLICATION_DATA              	3	3	outbound	0->26
# 	Frame: 38	1618084979.854925	inbound 	31
# 		Record: 13	APPLICATION_DATA              	3	3	inbound 	0->26
# 	Frame: 41	1618084979.857138	inbound 	1428
# 		Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 43	1618084979.857404	inbound 	1428
# 		Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 45	1618084979.857419	inbound 	1428
# 		Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 47	1618084979.857684	inbound 	1428
# 		Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 49	1618084979.857966	inbound 	1428
# 		Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 51	1618084979.857981	inbound 	1428
# 		Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 52	1618084979.858615	inbound 	1428
# 		Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 54	1618084979.858883	inbound 	1428
# 		Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 55	1618084979.85955	inbound 	1428
# 		Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 57	1618084979.859806	inbound 	1428
# 		Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 58	1618084979.860386	inbound 	1428
# 		Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 60	1618084979.8607	inbound 	1428
# 		Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# 		Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 61	1618084979.861361	inbound 	1428
# 		Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 63	1618084979.861617	inbound 	1428
# 		Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 64	1618084979.862236	inbound 	1428
# 		Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 66	1618084979.86249	inbound 	1428
# 		Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 67	1618084979.86331	inbound 	1428
# 		Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 69	1618084979.863573	inbound 	1428
# 		Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 70	1618084979.864119	inbound 	1428
# 		Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 72	1618084979.864413	inbound 	1428
# 		Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 73	1618084979.865184	inbound 	1428
# 		Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 75	1618084979.86543	inbound 	1428
# 		Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 76	1618084979.866101	inbound 	1428
# 		Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# 		Record: 16	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 78	1618084979.866388	inbound 	1428
# 		Record: 16	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 79	1618084979.866875	inbound 	1428
# 		Record: 16	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 81	1618084979.867162	inbound 	1428
# 		Record: 16	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 82	1618084979.867738	inbound 	1428
# 		Record: 16	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 84	1618084979.86803	inbound 	1428
# 		Record: 16	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 85	1618084979.87632	outbound	177
# 		Record: 17	APPLICATION_DATA              	3	3	outbound	0->172
# 	Frame: 86	1618084979.876455	outbound	81
# 		Record: 18	APPLICATION_DATA              	3	3	outbound	0->76
# 	Frame: 87	1618084979.887414	inbound 	1428
# 		Record: 18	APPLICATION_DATA              	3	3	inbound 	0->76
# 	Frame: 88	1618084979.887689	inbound 	1428
# 		Record: 18	APPLICATION_DATA              	3	3	inbound 	0->76
# 	Frame: 91	1618084979.887928	inbound 	1428
# 		Record: 18	APPLICATION_DATA              	3	3	inbound 	0->76
# 	Frame: 93	1618084979.888212	inbound 	1428
# 		Record: 18	APPLICATION_DATA              	3	3	inbound 	0->76
# 	Frame: 95	1618084979.888889	outbound	80
# 		Record: 19	APPLICATION_DATA              	3	3	outbound	0->75
# 	Frame: 96	1618084979.889503	outbound	80
# 		Record: 20	APPLICATION_DATA              	3	3	outbound	0->75
# 	Frame: 97	1618084979.889578	outbound	80
# 		Record: 21	APPLICATION_DATA              	3	3	outbound	0->75
# 	Frame: 98	1618084979.889643	outbound	80
# 		Record: 22	APPLICATION_DATA              	3	3	outbound	0->75
# 	Frame: 99	1618084979.889699	outbound	80
# 		Record: 23	APPLICATION_DATA              	3	3	outbound	0->75
# 	Frame: 100	1618084979.889755	outbound	81
# 		Record: 24	APPLICATION_DATA              	3	3	outbound	0->76
# 	Frame: 101	1618084979.890087	inbound 	1428
# 		Record: 24	APPLICATION_DATA              	3	3	inbound 	0->76
# 	Frame: 102	1618084979.890343	inbound 	1428
# 		Record: 24	APPLICATION_DATA              	3	3	inbound 	0->76
# 	Frame: 104	1618084979.890853	inbound 	1428
# 		Record: 24	APPLICATION_DATA              	3	3	inbound 	0->76
# 		Record: 25	APPLICATION_DATA              	3	3	inbound 	666->13817
# 	Frame: 105	1618084979.890863	inbound 	1428
# 		Record: 25	APPLICATION_DATA              	3	3	inbound 	666->13817
# 	Frame: 107	1618084979.89169	inbound 	1428
# 		Record: 25	APPLICATION_DATA              	3	3	inbound 	666->13817
# 	Frame: 108	1618084979.891947	inbound 	1428
# 		Record: 25	APPLICATION_DATA              	3	3	inbound 	666->13817
# 	Frame: 111	1618084979.892813	inbound 	1428
# 		Record: 25	APPLICATION_DATA              	3	3	inbound 	666->13817
# 	Frame: 112	1618084979.892825	inbound 	1428
# 		Record: 25	APPLICATION_DATA              	3	3	inbound 	666->13817
# 	Frame: 191	1618084979.997747	outbound	83
# 		Record: 38	APPLICATION_DATA              	3	3	outbound	0->78
# 	Frame: 192	1618084979.999087	outbound	84
# 		Record: 39	APPLICATION_DATA              	3	3	outbound	0->79
# 	Frame: 193	1618084979.999217	outbound	67
# 		Record: 40	APPLICATION_DATA              	3	3	outbound	0->62
# 	Frame: 199	1618084980.031475	inbound 	1428
# 		Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 200	1618084980.031481	inbound 	1428
# 		Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 202	1618084980.031983	inbound 	1428
# 		Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 203	1618084980.031991	inbound 	1428
# 		Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 205	1618084980.032607	inbound 	1428
# 		Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 206	1618084980.032863	inbound 	1428
# 		Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 208	1618084980.033114	inbound 	1428
# 		Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 209	1618084980.033374	inbound 	1428
# 		Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 211	1618084980.033886	inbound 	1428
# 		Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 212	1618084980.034143	inbound 	1428
# 		Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 214	1618084980.034657	inbound 	1428
# 		Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# 	Frame: 215	1618084980.034664	inbound 	1428
# 		Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# 		Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 217	1618084980.035245	inbound 	1428
# 		Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 218	1618084980.035499	inbound 	1428
# 		Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 220	1618084980.036017	inbound 	1428
# 		Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 221	1618084980.03627	inbound 	1428
# 		Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 223	1618084980.036781	inbound 	1428
# 		Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 224	1618084980.036788	inbound 	1428
# 		Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 226	1618084980.037384	inbound 	1428
# 		Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 227	1618084980.037634	inbound 	1428
# 		Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 229	1618084980.038143	inbound 	1428
# 		Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 230	1618084980.038403	inbound 	1428
# 		Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# 	Frame: 232	1618084980.038937	inbound 	1428
# 		Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 233	1618084980.038942	inbound 	1428
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 235	1618084980.039452	inbound 	1428
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 236	1618084980.039713	inbound 	1428
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 238	1618084980.040276	inbound 	1428
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 239	1618084980.040534	inbound 	1428
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 241	1618084980.041105	inbound 	1428
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 242	1618084980.041111	inbound 	1428
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 250	1618084980.041606	inbound 	1428
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 251	1618084980.0419	inbound 	1428
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 253	1618084980.042398	inbound 	1428
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 254	1618084980.04271	inbound 	1428
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 	Frame: 256	1618084980.043233	inbound 	1428
# 		Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# 		Record: 44	APPLICATION_DATA              	3	3	inbound 	666->16401
# 	Frame: 257	1618084980.043492	inbound 	1428
# 		Record: 44	APPLICATION_DATA              	3	3	inbound 	666->16401
# 	Frame: 259	1618084980.044034	inbound 	1428
# 		Record: 44	APPLICATION_DATA              	3	3	inbound 	666->16401
# 	Frame: 260	1618084980.04404	inbound 	1428
# 		Record: 44	APPLICATION_DATA              	3	3	inbound 	666->16401
# 	Frame: 262	1618084980.044697	inbound 	1428
# 		Record: 44	APPLICATION_DATA              	3	3	inbound 	666->16401
# 	Frame: 263	1618084980.044944	inbound 	1428
# 		Record: 44	APPLICATION_DATA              	3	3	inbound 	666->16401
# 	Frame: 265	1618084980.045457	inbound 	1428
# 		Record: 44	APPLICATION_DATA              	3	3	inbound 	666->16401
# 	Frame: 266	1618084980.045463	inbound 	1428
# 		Record: 44	APPLICATION_DATA              	3	3	inbound 	666->16401
# 	Frame: 268	1618084980.045967	inbound 	1428
# 		Record: 44	APPLICATION_DATA              	3	3	inbound 	666->16401
# 	Frame: 269	1618084980.046225	inbound 	1428
# 		Record: 44	APPLICATION_DATA              	3	3	inbound 	666->16401
# 	Frame: 271	1618084980.046733	inbound 	1428
# 		Record: 44	APPLICATION_DATA              	3	3	inbound 	666->16401
# 	Frame: 272	1618084980.046997	inbound 	1428
# 		Record: 49	APPLICATION_DATA              	3	3	inbound 	281->16401
# 	Frame: 374	1618084980.065235	inbound 	1428
# 		Record: 49	APPLICATION_DATA              	3	3	inbound 	281->16401
# 	Frame: 376	1618084980.065494	inbound 	1428
# 		Record: 49	APPLICATION_DATA              	3	3	inbound 	281->16401
# 	Frame: 377	1618084980.06574	inbound 	1428
# 		Record: 49	APPLICATION_DATA              	3	3	inbound 	281->16401
# 	Frame: 379	1618084980.066001	inbound 	1428
# 		Record: 49	APPLICATION_DATA              	3	3	inbound 	281->16401
# 	Frame: 380	1618084980.0665	inbound 	1428
# 		Record: 49	APPLICATION_DATA              	3	3	inbound 	281->16401
# 		Record: 50	APPLICATION_DATA              	3	3	inbound 	979->12592
# 	Frame: 382	1618084980.067009	inbound 	1428
# 		Record: 50	APPLICATION_DATA              	3	3	inbound 	979->12592
# 	Frame: 383	1618084980.067013	inbound 	1428
# 		Record: 50	APPLICATION_DATA              	3	3	inbound 	979->12592
# 	Frame: 385	1618084980.067553	inbound 	1428
# 		Record: 50	APPLICATION_DATA              	3	3	inbound 	979->12592
# 	Frame: 386	1618084980.06782	inbound 	1428
# 		Record: 50	APPLICATION_DATA              	3	3	inbound 	979->12592
# 	Frame: 390	1618084980.06832	inbound 	1428
# 		Record: 50	APPLICATION_DATA              	3	3	inbound 	979->12592
# 	Frame: 391	1618084980.068581	inbound 	1428
# 		Record: 50	APPLICATION_DATA              	3	3	inbound 	979->12592
# 	Frame: 393	1618084980.069095	inbound 	1428
# 		Record: 50	APPLICATION_DATA              	3	3	inbound 	979->12592
# 	Frame: 394	1618084980.069099	inbound 	1428
# 		Record: 50	APPLICATION_DATA              	3	3	inbound 	979->12592
# 	Frame: 396	1618084980.069679	inbound 	1428
# 		Record: 50	APPLICATION_DATA              	3	3	inbound 	979->12592
# 		Record: 51	APPLICATION_DATA              	3	3	inbound 	724->868
# 	Frame: 397	1618084980.069936	inbound 	1428
# 		Record: 51	APPLICATION_DATA              	3	3	inbound 	724->868
# 		Record: 52	APPLICATION_DATA              	3	3	inbound 	169->16401
# 	Frame: 399	1618084980.070441	inbound 	1428
# 		Record: 52	APPLICATION_DATA              	3	3	inbound 	169->16401
# 	Frame: 400	1618084980.070706	inbound 	1428
# 		Record: 52	APPLICATION_DATA              	3	3	inbound 	169->16401
# 	Frame: 405	1618084980.07121	inbound 	1428
# 		Record: 52	APPLICATION_DATA              	3	3	inbound 	169->16401
# 	Frame: 410	1618084980.071461	inbound 	1428
# 		Record: 52	APPLICATION_DATA              	3	3	inbound 	169->16401
# 	Frame: 412	1618084980.071979	inbound 	1428
# 		Record: 52	APPLICATION_DATA              	3	3	inbound 	169->16401
# 	Frame: 413	1618084980.071989	inbound 	1428
# 		Record: 52	APPLICATION_DATA              	3	3	inbound 	169->16401
# 	Frame: 417	1618084980.072569	inbound 	1428
# 		Record: 52	APPLICATION_DATA              	3	3	inbound 	169->16401
# 	Frame: 418	1618084980.07283	inbound 	1428
# 		Record: 58	APPLICATION_DATA              	3	3	inbound 	73->16401
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 	Frame: 620	1618084980.095839	inbound 	1428
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 	Frame: 621	1618084980.096095	inbound 	1428
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 	Frame: 623	1618084980.096099	inbound 	1428
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 	Frame: 624	1618084980.096601	inbound 	1428
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 	Frame: 626	1618084980.096857	inbound 	1428
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 	Frame: 627	1618084980.096861	inbound 	1428
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 	Frame: 629	1618084980.097365	inbound 	1428
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 	Frame: 630	1618084980.097619	inbound 	1428
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 	Frame: 632	1618084980.097623	inbound 	1428
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 	Frame: 633	1618084980.098134	inbound 	1428
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 	Frame: 635	1618084980.098387	inbound 	1428
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 	Frame: 636	1618084980.09839	inbound 	1428
# 		Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# 		Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# 	Frame: 638	1618084980.098638	inbound 	1428
# 		Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# 	Frame: 639	1618084980.098641	inbound 	1428
# 		Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# 	Frame: 641	1618084980.09889	inbound 	1428
# 		Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# 	Frame: 642	1618084980.098893	inbound 	1428
# 		Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# 	Frame: 644	1618084980.099142	inbound 	1428
# 		Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# 	Frame: 645	1618084980.099145	inbound 	1428
# 		Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# 	Frame: 647	1618084980.099394	inbound 	1428
# 		Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# 	Frame: 648	1618084980.099649	inbound 	1428
# 		Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# 	Frame: 650	1618084980.099652	inbound 	1428
# 		Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# 	Frame: 651	1618084980.0999	inbound 	1428
# 		Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# 	Frame: 653	1618084980.099904	inbound 	1428
# 		Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# 		Record: 61	APPLICATION_DATA              	3	3	inbound 	739->13926
# 	Frame: 654	1618084980.099905	inbound 	1428
# 		Record: 61	APPLICATION_DATA              	3	3	inbound 	739->13926
# 	Frame: 656	1618084980.100187	inbound 	1428
# 		Record: 61	APPLICATION_DATA              	3	3	inbound 	739->13926
# 	Frame: 657	1618084980.100192	inbound 	1428
# 		Record: 61	APPLICATION_DATA              	3	3	inbound 	739->13926
# 	Frame: 659	1618084980.100454	inbound 	1428
# 		Record: 61	APPLICATION_DATA              	3	3	inbound 	739->13926
# 	Frame: 660	1618084980.10071	inbound 	1428
# 		Record: 61	APPLICATION_DATA              	3	3	inbound 	739->13926
# 	Frame: 662	1618084980.100716	inbound 	1428
# 		Record: 61	APPLICATION_DATA              	3	3	inbound 	739->13926
# 	Frame: 663	1618084980.100993	inbound 	1428
# 		Record: 61	APPLICATION_DATA              	3	3	inbound 	739->13926
# 	Frame: 665	1618084980.100999	inbound 	1428
# 		Record: 61	APPLICATION_DATA              	3	3	inbound 	739->13926
# 	Frame: 666	1618084980.101282	inbound 	1428
# 		Record: 61	APPLICATION_DATA              	3	3	inbound 	739->13926
# 	Frame: 668	1618084980.101289	inbound 	390
# 		Record: 61	APPLICATION_DATA              	3	3	inbound 	739->13926

# %%
print("\n".join([str(r) for r in flow.tls_records]))
# Out:
# Record: 0	CLIENT_HELLO                  	3	1	outbound	0->512
# Record: 1	SERVER_HELLO                  	3	3	inbound 	0->122
# Record: 2	CHANGE_CIPHER_SPEC            	3	3	inbound 	127->1
# Record: 3	APPLICATION_DATA              	3	3	inbound 	133->36
# Record: 4	APPLICATION_DATA              	3	3	inbound 	174->5340
# Record: 5	APPLICATION_DATA              	3	3	inbound 	1235->281
# Record: 6	APPLICATION_DATA              	3	3	inbound 	93->53
# Record: 7	CHANGE_CIPHER_SPEC            	3	3	outbound	0->1
# Record: 8	APPLICATION_DATA              	3	3	outbound	6->53
# Record: 9	APPLICATION_DATA              	3	3	outbound	0->87
# Record: 10	APPLICATION_DATA              	3	3	outbound	0->358
# Record: 11	APPLICATION_DATA              	3	3	inbound 	0->57
# Record: 12	APPLICATION_DATA              	3	3	outbound	0->26
# Record: 13	APPLICATION_DATA              	3	3	inbound 	0->26
# Record: 14	APPLICATION_DATA              	3	3	inbound 	0->16401
# Record: 15	APPLICATION_DATA              	3	3	inbound 	698->16401
# Record: 16	APPLICATION_DATA              	3	3	inbound 	1396->16401
# Record: 17	APPLICATION_DATA              	3	3	outbound	0->172
# Record: 18	APPLICATION_DATA              	3	3	outbound	0->76
# Record: 19	APPLICATION_DATA              	3	3	outbound	0->75
# Record: 20	APPLICATION_DATA              	3	3	outbound	0->75
# Record: 21	APPLICATION_DATA              	3	3	outbound	0->75
# Record: 22	APPLICATION_DATA              	3	3	outbound	0->75
# Record: 23	APPLICATION_DATA              	3	3	outbound	0->75
# Record: 24	APPLICATION_DATA              	3	3	outbound	0->76
# Record: 25	APPLICATION_DATA              	3	3	inbound 	666->13817
# Record: 26	APPLICATION_DATA              	3	3	outbound	0->75
# Record: 27	APPLICATION_DATA              	3	3	inbound 	0->5723
# Record: 28	APPLICATION_DATA              	3	3	inbound 	16->4547
# Record: 29	APPLICATION_DATA              	3	3	inbound 	0->1074
# Record: 30	APPLICATION_DATA              	3	3	inbound 	0->1916
# Record: 31	APPLICATION_DATA              	3	3	inbound 	0->950
# Record: 32	APPLICATION_DATA              	3	3	inbound 	0->916
# Record: 33	APPLICATION_DATA              	3	3	inbound 	0->892
# Record: 34	APPLICATION_DATA              	3	3	inbound 	0->769
# Record: 35	APPLICATION_DATA              	3	3	inbound 	0->1854
# Record: 36	APPLICATION_DATA              	3	3	inbound 	0->642
# Record: 37	APPLICATION_DATA              	3	3	outbound	0->89
# Record: 38	APPLICATION_DATA              	3	3	outbound	0->78
# Record: 39	APPLICATION_DATA              	3	3	outbound	0->79
# Record: 40	APPLICATION_DATA              	3	3	outbound	0->62
# Record: 41	APPLICATION_DATA              	3	3	inbound 	0->16401
# Record: 42	APPLICATION_DATA              	3	3	inbound 	698->16401
# Record: 43	APPLICATION_DATA              	3	3	inbound 	1396->16401
# Record: 44	APPLICATION_DATA              	3	3	inbound 	666->16401
# Record: 45	APPLICATION_DATA              	3	3	inbound 	1364->12087
# Record: 46	APPLICATION_DATA              	3	3	inbound 	604->16401
# Record: 47	APPLICATION_DATA              	3	3	inbound 	1302->12556
# Record: 48	APPLICATION_DATA              	3	3	inbound 	1011->16401
# Record: 49	APPLICATION_DATA              	3	3	inbound 	281->16401
# Record: 50	APPLICATION_DATA              	3	3	inbound 	979->12592
# Record: 51	APPLICATION_DATA              	3	3	inbound 	724->868
# Record: 52	APPLICATION_DATA              	3	3	inbound 	169->16401
# Record: 53	APPLICATION_DATA              	3	3	inbound 	867->16401
# Record: 54	APPLICATION_DATA              	3	3	inbound 	137->16401
# Record: 55	APPLICATION_DATA              	3	3	inbound 	835->16401
# Record: 56	APPLICATION_DATA              	3	3	inbound 	105->16401
# Record: 57	APPLICATION_DATA              	3	3	inbound 	803->16401
# Record: 58	APPLICATION_DATA              	3	3	inbound 	73->16401
# Record: 59	APPLICATION_DATA              	3	3	inbound 	771->16401
# Record: 60	APPLICATION_DATA              	3	3	inbound 	41->16401
# Record: 61	APPLICATION_DATA              	3	3	inbound 	739->13926

# %%
remaining_record_size = 0
is_unlabeled = lambda x: pd.isna(main_flow.loc[x, 'tls.record.content_type'])
rows = []
remaining_bytes = 0

for i in range(main_flow.shape[0]):
    frame_number = int(main_flow.loc[i, 'frame.number'])
    frame_length = int(main_flow.at[i, 'tcp.len'])
    print(f"Process frame: {frame_number}")
    row = new_row(main_flow, i)
    if is_unlabeled(i):
        row['tls.record.version.major'] = rows[-1]['tls.record.version.major']
        row['tls.record.version.minor'] = rows[-1]['tls.record.version.minor']
        if remaining_bytes > 0:
            row = packet_part_of_previous_frame(row)
            rows.append(row)
            remaining_bytes -= row['tcp.len']
            
            if remaining_bytes < 0:
                frame_starts_at = 0
                tls_length = 0
                while frame_starts_at + tls_length + 5 < frame_length:
                    tmp, frame_starts_at = packet_contains_new_frame(rows[-1].copy(), frame_number, frame_starts_at + tls_length)
                    consumed = tmp['tcp.len'] - frame_starts_at
                    tls_length = tmp['tls.record.length']
                    remaining_bytes = tls_length - consumed
                    print(f"\t{frame_starts_at} + {tls_length} + 5 = {frame_starts_at+tls_length+5} < {frame_length}")
                    print(f"\tContains new frame starting at {frame_starts_at}: {tmp['tls.record.content_type']} {tmp['tls.record.length']}")
                    rows.append(tmp)
                
        elif packet_starts_with_tls_header(pth_to_trace, frame_number, major, minor):
            print(f'\tFrame {frame_number} starts with TLS Header')
            tmp, frame_starts_at = packet_contains_new_frame(row, frame_number, 0)
            tls_length = tmp['tls.record.length']
            rows.append(tmp)
            print(f"\tContains new frame starting at {frame_starts_at}: {tmp['tls.record.content_type']} {tmp['tls.record.length']}")
            while frame_starts_at + tls_length + 5 < frame_length:
                tmp, frame_starts_at = packet_contains_new_frame(rows[-1].copy(), frame_number, frame_starts_at + tls_length)
                consumed = tmp['tcp.len'] - frame_starts_at
                tls_length = tmp['tls.record.length']
                remaining_bytes = tls_length - consumed
                print(f"\t{frame_starts_at} + {tls_length} + 5 = {frame_starts_at+tls_length+5} < {frame_length}")
                print(f"\tContains new frame starting at {frame_starts_at}: {tmp['tls.record.content_type']} {tmp['tls.record.length']}")
                rows.append(tmp)
            remaining_bytes = rows[-1]['tls.record.length'] - (frame_length - (frame_starts_at + 5))
            print(f"\t{remaining_bytes} bytes remain")
        else:
            print(f"\tUnexpected contingency, remaining_bytes = {remaining_bytes}")
        #     groupdict = extract_record_info_re(pth_to_trace, main_flow.loc[i, 'frame.number'], major, minor)
        #     print("\t", groupdict)
        
    else:
        major = int(main_flow.at[i, 'tls.record.version'][-4:-2])
        minor = int(main_flow.at[i, 'tls.record.version'][-2:])
        row['tls.record.version.major'] = major
        row['tls.record.version.minor'] = minor
        row['_ws.col.Info'] = main_flow.at[i, '_ws.col.Info']
        record_types = main_flow.at[i, 'tls.record.content_type'].split(',')
        record_lengths = main_flow.at[i, 'tls.record.length'].split(',')
        tls_handshake_types = None
        assert len(record_types) == len(record_lengths)
        frame_content = 0
        for j, (t, l) in enumerate(zip(record_types, record_lengths)):
            tmp = row.copy()
            tmp['tls.frame_number'] = row['tls.frame_number'] + j
            tmp['tls.record.content_type'] = int(t)
            tmp['tls.record.length'] = int(l)
            frame_content += tmp['tls.record.length'] + 5
            if tmp['tls.record.content_type'] != 23 and not pd.isna(main_flow.at[i, 'tls.handshake.type']):
                if tls_handshake_types is None:
                    # tls_handshake_types = str(int(main_flow.at[i, 'tls.handshake.type'])).split(',')
                    tls_handshake_types = [int(main_flow.at[i, 'tls.handshake.type'])]
                tmp['tls.handshake.type'] = int(tls_handshake_types.pop()) if len(tls_handshake_types) > 0 else None
            rows.append(tmp)
        print(f"\tFrame {frame_number} has v {major}.{minor}, type {main_flow.at[i, 'tls.record.content_type']} and lengths {main_flow.loc[i, 'tls.record.length']}")
        
        # print(rows[-1], frame_content)
        if rows[-1]['tcp.len'] > frame_content:
            groupdict = extract_record_info_re(pth_to_trace, main_flow.at[i, 'frame.number'], major, minor, rows[-1]['tls.record.length'])
            tmp = rows[-1].copy()
            tmp['tls.frame_number'] = tmp['tls.frame_number'] + 1
            tmp['tls.record.content_type'] = int(groupdict['recType'])
            tmp['tls.record.length'] = frame_size_from_group_dict(groupdict)
            tmp['tls.handshake.typ'] = None
            rows.append(tmp)
            consumed = tmp['tcp.len'] - get_header_start_byte_from_group_dict(groupdict)
            remaining_bytes = tmp['tls.record.length'] - consumed
            print("\t", f"Opened new frame, size {tmp['tls.record.length']}, consumed {consumed}, remaining {remaining_bytes}")

# %%
pd.DataFrame.from_dict(rows)
# Out:
#     frame_number  frame.time_epoch         ip.src  tcp.srcport         ip.dst  \
# 0             72      1.618235e+09     172.17.0.2        48762  18.205.93.255
# 1             74      1.618235e+09  18.205.93.255          443     172.17.0.2
# 2             74      1.618235e+09  18.205.93.255          443     172.17.0.2
# 3             76      1.618235e+09  18.205.93.255          443     172.17.0.2
# 4             78      1.618235e+09  18.205.93.255          443     172.17.0.2
# 5             78      1.618235e+09  18.205.93.255          443     172.17.0.2
# 6             80      1.618235e+09  18.205.93.255          443     172.17.0.2
# 7             80      1.618235e+09  18.205.93.255          443     172.17.0.2
# 8             80      1.618235e+09  18.205.93.255          443     172.17.0.2
# 9             91      1.618235e+09     172.17.0.2        48762  18.205.93.255
# 10            91      1.618235e+09     172.17.0.2        48762  18.205.93.255
# 11            91      1.618235e+09     172.17.0.2        48762  18.205.93.255
# 12            93      1.618235e+09     172.17.0.2        48762  18.205.93.255
# 13            94      1.618235e+09     172.17.0.2        48762  18.205.93.255
# 14           147      1.618235e+09  18.205.93.255          443     172.17.0.2
# 15           147      1.618235e+09  18.205.93.255          443     172.17.0.2
# 16           149      1.618235e+09  18.205.93.255          443     172.17.0.2
# 17           151      1.618235e+09     172.17.0.2        48762  18.205.93.255
# 18           152      1.618235e+09  18.205.93.255          443     172.17.0.2
# 19           154      1.618235e+09  18.205.93.255          443     172.17.0.2
# 20           156      1.618235e+09  18.205.93.255          443     172.17.0.2
# 21           158      1.618235e+09  18.205.93.255          443     172.17.0.2
# 22           158      1.618235e+09  18.205.93.255          443     172.17.0.2
# 23           160      1.618235e+09  18.205.93.255          443     172.17.0.2
# 24           162      1.618235e+09  18.205.93.255          443     172.17.0.2
# 25           164      1.618235e+09  18.205.93.255          443     172.17.0.2
# 26           164      1.618235e+09  18.205.93.255          443     172.17.0.2
# 27           166      1.618235e+09  18.205.93.255          443     172.17.0.2
# 28           186      1.618235e+09  18.205.93.255          443     172.17.0.2
# 29           188      1.618235e+09  18.205.93.255          443     172.17.0.2
# 30           188      1.618235e+09  18.205.93.255          443     172.17.0.2
# 31           190      1.618235e+09  18.205.93.255          443     172.17.0.2
# 32           192      1.618235e+09  18.205.93.255          443     172.17.0.2
# 33           194      1.618235e+09  18.205.93.255          443     172.17.0.2
# 34           194      1.618235e+09  18.205.93.255          443     172.17.0.2
# 35           196      1.618235e+09  18.205.93.255          443     172.17.0.2
# 36           197      1.618235e+09  18.205.93.255          443     172.17.0.2
# 37           197      1.618235e+09  18.205.93.255          443     172.17.0.2
# 38           257      1.618235e+09     172.17.0.2        48762  18.205.93.255
# 39           307      1.618235e+09  18.205.93.255          443     172.17.0.2
# 40           308      1.618235e+09  18.205.93.255          443     172.17.0.2
# 41           309      1.618235e+09  18.205.93.255          443     172.17.0.2
# 42           310      1.618235e+09  18.205.93.255          443     172.17.0.2
# 43           311      1.618235e+09  18.205.93.255          443     172.17.0.2
# 44           312      1.618235e+09  18.205.93.255          443     172.17.0.2
# 45           312      1.618235e+09  18.205.93.255          443     172.17.0.2
# 46          1750      1.618235e+09     172.17.0.2        48762  18.205.93.255
# 47          1752      1.618235e+09     172.17.0.2        48762  18.205.93.255
# 48          1767      1.618235e+09  18.205.93.255          443     172.17.0.2
# 49          1769      1.618235e+09  18.205.93.255          443     172.17.0.2
# 50          1771      1.618235e+09  18.205.93.255          443     172.17.0.2
#
#     tcp.dstport  tcp.len  tls.frame_number  tls.handshake.type  \
# 0           443      513                 0                 1.0
# 1         48762     1460                 1                 2.0
# 2         48762     1460                 2                 2.0
# 3         48762     1460                 2                 NaN
# 4         48762     1460                 2                 NaN
# 5         48762     1460                 3                 NaN
# 6         48762      410                 3                 NaN
# 7         48762      410                 4                 NaN
# 8         48762      410                 5                 NaN
# 9           443      126                 6                16.0
# 10          443      126                 7                 NaN
# 11          443      126                 8                 NaN
# 12          443      177                 9                 NaN
# 13          443      253                10                 NaN
# 14        48762       51                11                 NaN
# 15        48762       51                12                 NaN
# 16        48762       69                13                 NaN
# 17          443       38                14                 NaN
# 18        48762       38                15                 NaN
# 19        48762     1460                17                 NaN
# 20        48762     1460                17                 NaN
# 21        48762     1460                17                 NaN
# 22        48762     1460                18                 NaN
# 23        48762     1460                18                 NaN
# 24        48762     1460                18                 NaN
# 25        48762     1460                18                 NaN
# 26        48762     1460                19                 NaN
# 27        48762     1460                19                 NaN
# 28        48762     1460                19                 NaN
# 29        48762     1460                19                 NaN
# 30        48762     1460                20                 NaN
# 31        48762     1460                20                 NaN
# 32        48762     1460                20                 NaN
# 33        48762     1460                20                 NaN
# 34        48762     1460                21                 NaN
# 35        48762     1460                21                 NaN
# 36        48762     1451                21                 NaN
# 37        48762     1451                22                 NaN
# 38          443      357                23                 NaN
# 39        48762     1460                25                 NaN
# 40        48762     1460                25                 NaN
# 41        48762     1205                25                 NaN
# 42        48762     1460                27                 NaN
# 43        48762     1460                27                 NaN
# 44        48762      311                27                 NaN
# 45        48762      311                28                 NaN
# 46          443      177                29                 NaN
# 47          443       38                30                 NaN
# 48        48762       42                31                 NaN
# 49        48762     1460                33                 NaN
# 50        48762     1142                33                 NaN
#
#     tls.record.version.major  tls.record.version.minor  \
# 0                          3                         1
# 1                          3                         3
# 2                          3                         3
# 3                          3                         3
# 4                          3                         3
# 5                          3                         3
# 6                          3                         3
# 7                          3                         3
# 8                          3                         3
# 9                          3                         3
# 10                         3                         3
# 11                         3                         3
# 12                         3                         3
# 13                         3                         3
# 14                         3                         3
# 15                         3                         3
# 16                         3                         3
# 17                         3                         3
# 18                         3                         3
# 19                         3                         3
# 20                         3                         3
# 21                         3                         3
# 22                         3                         3
# 23                         3                         3
# 24                         3                         3
# 25                         3                         3
# 26                         3                         3
# 27                         3                         3
# 28                         3                         3
# 29                         3                         3
# 30                         3                         3
# 31                         3                         3
# 32                         3                         3
# 33                         3                         3
# 34                         3                         3
# 35                         3                         3
# 36                         3                         3
# 37                         3                         3
# 38                         3                         3
# 39                         3                         3
# 40                         3                         3
# 41                         3                         3
# 42                         3                         3
# 43                         3                         3
# 44                         3                         3
# 45                         3                         3
# 46                         3                         3
# 47                         3                         3
# 48                         3                         3
# 49                         3                         3
# 50                         3                         3
#
#                                          _ws.col.Info  \
# 0                                        Client Hello
# 1                                        Server Hello
# 2                                        Server Hello
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Client Key Exchange, Change Cipher Spec, Encry...
# 10  Client Key Exchange, Change Cipher Spec, Encry...
# 11  Client Key Exchange, Change Cipher Spec, Encry...
# 12                                   Application Data
# 13                                   Application Data
# 14    Change Cipher Spec, Encrypted Handshake Message
# 15    Change Cipher Spec, Encrypted Handshake Message
# 16                                   Application Data
# 17                                   Application Data
# 18                                   Application Data
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                   Application Data
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                   Application Data
# 47                                   Application Data
# 48                                   Application Data
# 49                                                NaN
# 50                                                NaN
#
#     tls.record.content_type  tls.record.length  tls.handshake.typ
# 0                        22              508.0                NaN
# 1                        22              106.0                NaN
# 2                        16             3843.0                NaN
# 3                        16                NaN                NaN
# 4                        16                NaN                NaN
# 5                        16              479.0                NaN
# 6                        16                NaN                NaN
# 7                        16              333.0                NaN
# 8                        16                4.0                NaN
# 9                        22               70.0                NaN
# 10                       20                1.0                NaN
# 11                       22               40.0                NaN
# 12                       23              172.0                NaN
# 13                       23              248.0                NaN
# 14                       20                1.0                NaN
# 15                       22               40.0                NaN
# 16                       23               64.0                NaN
# 17                       23               33.0                NaN
# 18                       23               33.0                NaN
# 19                       17             4120.0                NaN
# 20                       17                NaN                NaN
# 21                       17                NaN                NaN
# 22                       17             4120.0                NaN
# 23                       17                NaN                NaN
# 24                       17                NaN                NaN
# 25                       17                NaN                NaN
# 26                       17             4120.0                NaN
# 27                       17                NaN                NaN
# 28                       17                NaN                NaN
# 29                       17                NaN                NaN
# 30                       17             4120.0                NaN
# 31                       17                NaN                NaN
# 32                       17                NaN                NaN
# 33                       17                NaN                NaN
# 34                       17             3888.0                NaN
# 35                       17                NaN                NaN
# 36                       17                NaN                NaN
# 37                       17               33.0                NaN
# 38                       23              352.0                NaN
# 39                       17             4120.0                NaN
# 40                       17                NaN                NaN
# 41                       17                NaN                NaN
# 42                       17             3188.0                NaN
# 43                       17                NaN                NaN
# 44                       17                NaN                NaN
# 45                       17               33.0                NaN
# 46                       23              172.0                NaN
# 47                       23               33.0                NaN
# 48                       23               37.0                NaN
# 49                       17             2597.0                NaN
# 50                       17                NaN                NaN

# %%
int(main_flow.loc[0, 'tls.record.version'][-4:-2])
# Out:
# 3

# %%
def tmp(main_flow):
    for i, row in main_flow.iterrows():
        print(i, row['tls.record.length'])
        if i == 2:
            main_flow.at[i, 'tls.record.lenght'] = 10000
            print(main_flow.at[i, 'tls.record.lenght'] )
            
    print(main_flow.at[2, 'tls.record.lenght'] )
    return main_flow

# %%
mf = tmp(main_flow)
# Out:
# 0 508
# 1 106
# 2 nan
# 10000.0
# 3 3843
# 4 479,333,4
# 5 70,1,40
# 6 172
# 7 248
# 8 1,40
# 9 64
# 10 33
# 11 33
# 12 nan
# 13 nan
# 14 4120
# 15 nan
# 16 nan
# 17 4120
# 18 nan
# 19 nan
# 20 4120
# 21 nan
# 22 nan
# 23 4120
# 24 nan
# 25 3888,33
# 26 352
# 27 nan
# 28 nan
# 29 4120
# 30 nan
# 31 nan
# 32 3188,33
# 33 172
# 34 33
# 35 37
# 36 nan
# 37 2597
# 10000.0

# %%
s = """
0000  02 42 55 b3 54 37 02 42 ac 11 00 02 08 00 45 00   .BU.T7.B......E.
0010  00 d9 da 1f 40 00 40 06 43 20 ac 11 00 02 12 cd   ....@.@.C ......
0020  5d ff be 7a 01 bb ae 3d 18 ce d8 55 d2 c0 50 18   ]..z...=...U..P.
0030  01 f5 a8 98 00 00 17 03 03 00 ac 00 00 00 00 00   ................
0040  00 00 01 8a 01 b9 f4 be 8d ef 11 07 60 d7 2a 0a   ............`.*.
0050  c2 af ee 0d af 24 b7 30 af f5 86 38 ac 77 4c 1d   .....$.0...8.wL.
0060  dc cd ba b6 bc 71 dc 59 a9 66 7a 3c a3 87 63 4c   .....q.Y.fz<..cL
0070  20 2f f3 f3 65 9f b7 85 05 63 4e 7f 20 56 15 03    /..e....cN. V..
0080  03 ff 2f 74 c0 7b ed 3a bf 0c 7a a0 b8 21 03 16   0(.t.{.:..z..!..
0090  03 03 7b e6 7e 6f 63 8b e5 ee d1 ba 4a 14 03 03   ..{.~oc.....J...
00a0  1f 3a 74 65 ed c7 b9 ad 67 50 7f 58 17 03 03 99   .:te....gP.X....
00b0  94 5c b5 aa 40 a6 03 c4 d2 42 81 1a 17 03 03 dd   .\..@....B..|.V.
00c0  b7 b3 b8 da 4b ce 25 09 c5 28 96 94 5a 26 bc 15   ....K.%..(..Z&..
00d0  14 03 03 0f 56 e2 1e 53 5c 96 d5 92 fc d8 d8 d3   Ud..V..S\.......
00e0  9d ed 40 06 6b 44 17
"""

# %%
pattern = re.compile(
    "(?P<numBytes0>[0-9a-f]{4})?"              # Match byte numbers.
    "(?P<anyBytes0>  ([0-9a-f]{2} )*)?"        # Match any sequence of bytes.
    "(?P<recType>14|15|16|17)"               # Match TLS record type.
    "((?P<ascii1>   .{16}\n)(?P<numBytes2>[0-9a-f]{4} ))?"   # End of row. Match ASCII output, new line and byte numbers.
    " (?P<major>03)"                       # Match TLS major version
    "((?P<ascii2>   .{16}\n)(?P<numBytes3>[0-9a-f]{4} ))?"   # End of row. Match ASCII output, new line and byte numbers.
    " (?P<minor>03)"                       # Match TLS minor version.
    "((?P<ascii3>   .{16}\n)(?P<numBytes4>[0-9a-f]{4} ))?"   # End of row. Match ASCII output, new line and byte numbers.
    " (?P<length0>[0-9a-f]{2})"              # Match first byte of TLS record length.
    "((?P<ascii4>   .{16}\n)(?P<numBytes5>[0-9a-f]{4} ))?"   # End of row. Match ASCII output, new line and byte numbers.
    " (?P<length1>[0-9a-f]{2})"              # Match second byte of TLS record length.
)

# %%
print(s)
# Out:
# 0000  02 42 55 b3 54 37 02 42 ac 11 00 02 08 00 45 00   .BU.T7.B......E.
# 0010  00 d9 da 1f 40 00 40 06 43 20 ac 11 00 02 12 cd   ....@.@.C ......
# 0020  5d ff be 7a 01 bb ae 3d 18 ce d8 55 d2 c0 50 18   ]..z...=...U..P.
# 0030  01 f5 a8 98 00 00 17 03 03 00 ac 00 00 00 00 00   ................
# 0040  00 00 01 8a 01 b9 f4 be 8d ef 11 07 60 d7 2a 0a   ............`.*.
# 0050  c2 af ee 0d af 24 b7 30 af f5 86 38 ac 77 4c 1d   .....$.0...8.wL.
# 0060  dc cd ba b6 bc 71 dc 59 a9 66 7a 3c a3 87 63 4c   .....q.Y.fz<..cL
# 0070  20 2f f3 f3 65 9f b7 85 05 63 4e 7f 20 56 15 03    /..e....cN. V..
# 0080  03 ff 2f 74 c0 7b ed 3a bf 0c 7a a0 b8 21 03 16   0(.t.{.:..z..!..
# 0090  03 03 7b e6 7e 6f 63 8b e5 ee d1 ba 4a 14 03 03   ..{.~oc.....J...
# 00a0  1f 3a 74 65 ed c7 b9 ad 67 50 7f 58 17 03 03 99   .:te....gP.X....
# 00b0  94 5c b5 aa 40 a6 03 c4 d2 42 81 1a 17 03 03 dd   .\..@....B..|.V.
# 00c0  b7 b3 b8 da 4b ce 25 09 c5 28 96 94 5a 26 bc 15   ....K.%..(..Z&..
# 00d0  14 03 03 0f 56 e2 1e 53 5c 96 d5 92 fc d8 d8 d3   Ud..V..S\.......
# 00e0  9d ed 40 06 6b 44 17

# %%
pattern.search(s)
# Out:
# <re.Match object; span=(220, 258), match='0030  01 f5 a8 98 00 00 17 03 03 00 ac'>

# %%
pattern.search(s[258:])
# Out:
# <re.Match object; span=(254, 341), match='0070  20 2f f3 f3 65 9f b7 85 05 63 4e 7f 20 56 1>

# %%
pattern.search(s[599:])
# Out:
# <re.Match object; span=(37, 76), match='16   0(.t.{.:..z..!..\n0090  03 03 7b e6'>

# %%
pattern.search(s[676:])
# Out:
# <re.Match object; span=(27, 66), match='14 03 03   ..{.~oc.....J...\n00a0  1f 3a'>

# %%
pattern.search(s[742:])
# Out:
# <re.Match object; span=(31, 70), match='17 03 03 99   .:te....gP.X....\n00b0  94'>

# %%
pattern.search(s[812:])
# Out:
# <re.Match object; span=(34, 73), match='17 03 03 dd   .\\..@....B..|.V.\n00c0  b7'>

# %%
pattern.search(s[885:])
# Out:
# <re.Match object; span=(65, 85), match='00d0  14 03 03 0f 56'>

# %%
m = pattern.search(s)

# %%
m.groups()
# Out:
# ('0030',
#  '  01 f5 a8 98 00 00 ',
#  '00 ',
#  '17',
#  None,
#  None,
#  None,
#  '03',
#  None,
#  None,
#  None,
#  '03',
#  None,
#  None,
#  None,
#  '00',
#  None,
#  None,
#  None,
#  'ac')

# %%
m2 = pattern.search(s[812:])

# %%
m2.groupdict()
# Out:
# {'numBytes0': None,
#  'anyBytes0': None,
#  'recType': '17',
#  'ascii1': None,
#  'numBytes2': None,
#  'major': '03',
#  'ascii2': None,
#  'numBytes3': None,
#  'minor': '03',
#  'ascii3': None,
#  'numBytes4': None,
#  'length0': 'dd',
#  'ascii4': '   .\\..@....B..|.V.\n',
#  'numBytes5': '00c0 ',
#  'length1': 'b7'}

# %%
m.groupdict()
# Out:
# {'numBytes0': '0030',
#  'anyBytes0': '  01 f5 a8 98 00 00 ',
#  'recType': '17',
#  'ascii1': None,
#  'numBytes2': None,
#  'major': '03',
#  'ascii2': None,
#  'numBytes3': None,
#  'minor': '03',
#  'ascii3': None,
#  'numBytes4': None,
#  'length0': '00',
#  'ascii4': None,
#  'numBytes5': None,
#  'length1': 'ac'}

# %%
frame_size_from_group_dict(m.groupdict())
# Out:
# 172

# %%
([0-9a-f]{4})?(  ([0-9a-f]{2} )*)?(14|15|16|17)(   .{16}\n[0-9a-f]{4} )? (03)(   .{16}\n[0-9a-f]{4} )? (03)(   .{16}\n[0-9a-f]{4} )? ([0-9a-f]{2})(   .{16}\n[0-9a-f]{4} )? ([0-9a-f]{2})

# %%
0000  02 42 55 b3 54 37 02 42 ac 11 00 02 08 00 45 00   .BU.T7.B......E.
0010  00 d9 da 1f 40 00 40 06 43 20 ac 11 00 02 12 cd   ....@.@.C ......
0020  5d ff be 7a 01 bb ae 3d 18 ce d8 55 d2 c0 50 18   ]..z...=...U..P.
0030  01 f5 a8 98 00 00 17 03 03 00 ac 00 00 00 00 00   ................
0040  00 00 01 8a 01 b9 f4 be 8d ef 11 07 60 d7 2a 0a   ............`.*.
0050  c2 af ee 0d af 24 b7 30 af f5 86 38 ac 77 4c 1d   .....$.0...8.wL.
0060  dc cd ba b6 bc 71 dc 59 a9 66 7a 3c a3 87 63 4c   .....q.Y.fz<..cL
0070  20 2f f3 f3 65 9f b7 85 05 63 4e 7f 20 56 15 03    /..e....cN. V..
0080  03 ff 2f 74 c0 7b ed 3a bf 0c 7a a0 b8 21 03 16   0(.t.{.:..z..!..
0090  03 03 7b e6 7e 6f 63 8b e5 ee d1 ba 4a 14 03 03   ..{.~oc.....J...
00a0  1f 3a 74 65 ed c7 b9 ad 67 50 7f 58 17 03 03 99   .:te....gP.X....
00b0  94 5c b5 aa 40 a6 03 c4 d2 42 81 1a 17 03 03 dd   .\..@....B..|.V.
00c0  b7 b3 b8 da 4b ce 25 09 c5 28 96 94 5a 26 bc 15   ....K.%..(..Z&..
00d0  14 03 03 0f 56 15 03 03 5c 96 d5 92 fc d8 d8 d3   Ud..V..S\.......
00e0  9d ed 40 06 6b 44 17

# %%
zoom filter: ((ip.src == 172.17.0.2 && tcp.srcport == 48762) || (ip.dst == 172.17.0.2 && tcp.dstport == 48762)) && tcp.len > 0
